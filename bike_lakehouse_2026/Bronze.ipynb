# %% [markdown]
# #Reading from CSV file

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/src/src_crm/cust_info.csv")
)
display(df)

# %% [markdown]
# #Write it to Bronze Layer

# %%
df.write.mode("overwrite").saveAsTable("bronze.crm_cust_info")

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/src/src_crm/prd_info.csv")
)
display(df)

df.write.mode("overwrite").saveAsTable("bronze.crm_prd_info")

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/src/src_crm/sales_details.csv")
)
display(df)

df.write.mode("overwrite").saveAsTable("bronze.crm_sales_details")
